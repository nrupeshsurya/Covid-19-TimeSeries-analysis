# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import copy
import random
import warnings
from sklearn import linear_model
from sklearn import svm
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
warnings.filterwarnings('ignore')

random.seed(42)

# %%
df = pd.read_csv('../data/data_new.csv',index_col=0)
df.info()
filterX = ['new_cases',"weekly_new_cases_average","weekly_new_tests_average","positive_rate","total_vaccinations","people_vaccinated","people_fully_vaccinated","stringency_index","driving",
"walking","transit","retail_and_recreation_percent_change_from_baseline","grocery_and_pharmacy_percent_change_from_baseline","parks_percent_change_from_baseline","transit_stations_percent_change_from_baseline","workplaces_percent_change_from_baseline","residential_percent_change_from_baseline"]
filterY = ['new_cases']
df = df[filterX]
df1 = copy.deepcopy(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 416 entries, 2020-03-01 to 2021-04-20
# Data columns (total 28 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                416 non-null    object
#  1   total_cases                                         416 non-null    float64
#  2   new_cases                                           416 non-null    float64
#  3   weekly_new_cases_average                            416 non-null    float64
#  4   new_cases_yesterday                                 416 non-null    float64
#  5   new_deaths                                          416 non-null    float64
#  6   weeky_new_deaths_average                            416 non-null    float64
#  7   new_deaths_yesterday                                416 non-null    float64
#  8   new_tests                                           416 non-null    float64
#  9   weekly_new_tests_average                            416 non-null    float64
#  10  new_tests_yesterday                                 416 non-null    float64
#  11  positive_rate                                       416 non-null    float64
#  12  total_vaccinations                                  416 non-null    float64
#  13  total_vaccinations_yesterday                        416 non-null    float64
#  14  people_vaccinated                                   416 non-null    float64
#  15  people_vaccinated_yesterday                         416 non-null    float64
#  16  people_fully_vaccinated                             416 non-null    float64
#  17  people_fully_vaccinated_yesterday                   416 non-null    float64
#  18  stringency_index                                    416 non-null    float64
#  19  driving                                             416 non-null    float64
#  20  transit                                             416 non-null    float64
#  21  walking                                             416 non-null    float64
#  22  retail_and_recreation_percent_change_from_baseline  416 non-null    float64
#  23  grocery_and_pharmacy_percent_change_from_baseline   416 non-null    float64
#  24  parks_percent_change_from_baseline                  416 non-null    float64
#  25  transit_stations_percent_change_from_baseline       416 non-null    float64
#  26  workplaces_percent_change_from_baseline             416 non-null    float64
#  27  residential_percent_change_from_baseline            416 non-null    float64
# dtypes: float64(27), object(1)
# memory usage: 94.2+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 416 entries, 2020-03-01 to 2021-04-20
# Data columns (total 17 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   new_cases                                           416 non-null    float64
#  1   weekly_new_cases_average                            416 non-null    float64
#  2   weekly_new_tests_average                            416 non-null    float64
#  3   positive_rate                                       416 non-null    float64
#  4   total_vaccinations                                  416 non-null    float64
#  5   people_vaccinated                                   416 non-null    float64
#  6   people_fully_vaccinated                             416 non-null    float64
#  7   stringency_index                                    416 non-null    float64
#  8   driving                                             416 non-null    float64
#  9   walking                                             416 non-null    float64
#  10  transit                                             416 non-null    float64
#  11  retail_and_recreation_percent_change_from_baseline  416 non-null    float64
#  12  grocery_and_pharmacy_percent_change_from_baseline   416 non-null    float64
#  13  parks_percent_change_from_baseline                  416 non-null    float64
#  14  transit_stations_percent_change_from_baseline       416 non-null    float64
#  15  workplaces_percent_change_from_baseline             416 non-null    float64
#  16  residential_percent_change_from_baseline            416 non-null    float64
# dtypes: float64(17)
# memory usage: 58.5+ KB

# %%
df = df.astype(float)

# %%
scaler = StandardScaler()
scaler = scaler.fit(df)
df_train = scaler.transform(df)

# %%
def set_shape(fut):
    trainX = []
    trainY = []
    n_future = fut  # Number of days we want to predict into the future
    n_past = 7     # Number of past days we want to use to predict the future


    for i in range(n_past, len(df_train) - n_future +1):
        trainX.append(df_train[i - n_past:i, 0:df_train.shape[1]])
        trainY.append(df_train[i + n_future - 1:i + n_future, 0])

    trainX, trainY = np.array(trainX), np.array(trainY)

    print('trainX shape == {}.'.format(trainX.shape))
    print('trainY shape == {}.'.format(trainY.shape))
    return trainX,trainY

# %%
def test_train_split(trainX, trainY):
    testX = trainX[-15:]
    testY = trainY[-15:]

    trainX = trainX[:-15]
    trainY = trainY[:-15]

    trainDates = df1.index[:-15]
    testDates = df1.index[-15:]

    print('trainX shape == {}.'.format(trainX.shape))
    print('trainY shape == {}.'.format(trainY.shape))

    print('testX shape == {}.'.format(testX.shape))
    print('testY shape == {}.'.format(testY.shape))
    return testX,testY,trainDates,testDates,trainX,trainY

# %%
def plot(classifiers_names, evaluation):
    fig, axs = plt.subplots(1,3, figsize=(20, 5))
    axs = axs.ravel()

    # print(classifiers_names)

    for i in range(3):
        axs[i].bar(classifiers_names,evaluation[i])
        for tick in axs[i].get_xticklabels():
            tick.set_rotation(90)
    axs[0].set_title('MSE')
    axs[1].set_title('MAE')
    axs[2].set_title('R2')
    plt.show()

# %%
def predict_n_days(trainX, trainY, testX, testY, testDates,n):

    classifiers = [
        svm.SVR(),
        linear_model.SGDRegressor(random_state=42),
        GradientBoostingRegressor(random_state=42),
        linear_model.ARDRegression(),
        RandomForestRegressor(random_state = 42),
        linear_model.LinearRegression()]

    nsamples, nx, ny = trainX.shape
    train_new_dataset = trainX.reshape((nsamples,nx*ny))
    nsamples, nx, ny = testX.shape
    test_new_dataset = testX.reshape((nsamples,nx*ny))


    df1['Date'] = pd.to_datetime(df1.index)

    fig, axs = plt.subplots(2,3, figsize=(30, 15))
    fig.suptitle(f'Predicting {n} day(s) ahead in the future',fontsize=30)
    classifiers_names = ['svm','SGDRegressor','GradientBoostingRegressor','ARDRegression','RandomForestRegressor','LinearRegression']

    MSE_scores = []
    MAE_scores = []
    R2_scores = []

    axs = axs.ravel()   

    i=0
    for item in classifiers:
        clf = item
        clf.fit(train_new_dataset, trainY.ravel())
        forecast = (clf.predict(test_new_dataset))
        forecast = forecast.reshape(len(forecast), 1, 1)
        forecast_copies = np.repeat(forecast, df_train.shape[1], axis=-1)
        y_pred_future = scaler.inverse_transform(forecast_copies)[:,0]
        y_pred_future = y_pred_future[:,0]
        df_forecast = pd.DataFrame({'Date':testDates, 'Cases':y_pred_future})
        df_forecast['Date']=pd.to_datetime(df_forecast['Date'])
        axs[i].set_title(classifiers_names[i])
        axs[i].set_ylabel('Cases')
        testY_new = scaler.inverse_transform(np.repeat(testY,df_train.shape[1], axis=-1))[:,0]
        axs[i].plot(df_forecast['Date'], testY_new)
        axs[i].plot(df_forecast['Date'], df_forecast['Cases'])
        for tick in axs[i].get_xticklabels():
            tick.set_rotation(45)
        i+=1
        R2_scores.append(r2_score(testY,forecast.reshape(len(forecast),1)))
        MSE_scores.append(mean_squared_error(testY,forecast.reshape(len(forecast),1)))
        MAE_scores.append(mean_absolute_error(testY,forecast.reshape(len(forecast),1)))

    # print([f"{num:.5f} &" for num in R2_scores])
    # print([f"{num:.5f} & " for num in MSE_scores])
    # print([f"{num:.5f} &" for num in MAE_scores])

    plt.show()
    evaluation = [MSE_scores,MAE_scores,R2_scores]
    plot(classifiers_names, evaluation)

# %%
for i in range(1,8):
    trainX_new, trainY_new = set_shape(i)
    testX_new, testY_new,trainDates, testDates, trainX_new,trainY_new = test_train_split(trainX_new, trainY_new)
    predict_n_days(trainX_new, trainY_new, testX_new, testY_new, testDates,i)
# Out:
# trainX shape == (409, 7, 17).
# trainY shape == (409, 1).
# trainX shape == (394, 7, 17).
# trainY shape == (394, 1).
# testX shape == (15, 7, 17).
# testY shape == (15, 1).
# trainX shape == (408, 7, 17).
# trainY shape == (408, 1).
# trainX shape == (393, 7, 17).
# trainY shape == (393, 1).
# testX shape == (15, 7, 17).
# testY shape == (15, 1).
# trainX shape == (407, 7, 17).
# trainY shape == (407, 1).
# trainX shape == (392, 7, 17).
# trainY shape == (392, 1).
# testX shape == (15, 7, 17).
# testY shape == (15, 1).
# trainX shape == (406, 7, 17).
# trainY shape == (406, 1).
# trainX shape == (391, 7, 17).
# trainY shape == (391, 1).
# testX shape == (15, 7, 17).
# testY shape == (15, 1).
# trainX shape == (405, 7, 17).
# trainY shape == (405, 1).
# trainX shape == (390, 7, 17).
# trainY shape == (390, 1).
# testX shape == (15, 7, 17).
# testY shape == (15, 1).
# trainX shape == (404, 7, 17).
# trainY shape == (404, 1).
# trainX shape == (389, 7, 17).
# trainY shape == (389, 1).
# testX shape == (15, 7, 17).
# testY shape == (15, 1).
# trainX shape == (403, 7, 17).
# trainY shape == (403, 1).
# trainX shape == (388, 7, 17).
# trainY shape == (388, 1).
# testX shape == (15, 7, 17).
# testY shape == (15, 1).
