# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import pandas as pd
import matplotlib.dates as mdates
# import mplcyberpunk
plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('../data/data_new.csv', index_col=0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 416 entries, 2020-03-01 to 2021-04-20
# Data columns (total 28 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                416 non-null    object
#  1   total_cases                                         416 non-null    float64
#  2   new_cases                                           416 non-null    float64
#  3   weekly_new_cases_average                            416 non-null    float64
#  4   new_cases_yesterday                                 416 non-null    float64
#  5   new_deaths                                          416 non-null    float64
#  6   weeky_new_deaths_average                            416 non-null    float64
#  7   new_deaths_yesterday                                416 non-null    float64
#  8   new_tests                                           416 non-null    float64
#  9   weekly_new_tests_average                            416 non-null    float64
#  10  new_tests_yesterday                                 416 non-null    float64
#  11  positive_rate                                       416 non-null    float64
#  12  total_vaccinations                                  416 non-null    float64
#  13  total_vaccinations_yesterday                        416 non-null    float64
#  14  people_vaccinated                                   416 non-null    float64
#  15  people_vaccinated_yesterday                         416 non-null    float64
#  16  people_fully_vaccinated                             416 non-null    float64
#  17  people_fully_vaccinated_yesterday                   416 non-null    float64
#  18  stringency_index                                    416 non-null    float64
#  19  driving                                             416 non-null    float64
#  20  transit                                             416 non-null    float64
#  21  walking                                             416 non-null    float64
#  22  retail_and_recreation_percent_change_from_baseline  416 non-null    float64
#  23  grocery_and_pharmacy_percent_change_from_baseline   416 non-null    float64
#  24  parks_percent_change_from_baseline                  416 non-null    float64
#  25  transit_stations_percent_change_from_baseline       416 non-null    float64
#  26  workplaces_percent_change_from_baseline             416 non-null    float64
#  27  residential_percent_change_from_baseline            416 non-null    float64
# dtypes: float64(27), object(1)
# memory usage: 94.2+ KB

# %%
df = df.rename_axis('Dates').reset_index()
df['Dates'] = pd.to_datetime(df['Dates'])

# %%
plt.plot(df['Dates'],df['new_cases'])
plt.xticks(rotation='vertical')
plt.xlabel('Time--->')
plt.ylabel('New Cases--->')
plt.title('New Cases in USA')
plt.show()

# %%
plt.plot(df['Dates'],df['new_deaths'])
plt.xticks(rotation='vertical')
plt.xlabel('Time--->')
plt.ylabel('Deaths--->')
plt.title('Deaths in USA')
plt.show()

# %%
p1, = plt.plot(df['Dates'],df['new_tests'],label='total tests')
# p2, = plt.plot(df['Dates'],df['POSITIVE_TESTS'],label = 'positive tests')
# p3, = plt.plot(df['Dates'],df['TOTAL_ANTIGEN_TESTS'],label = 'antigen tests')
# plt.legend(handles=[p1, p2, p3], title='Legend', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation='vertical')
plt.xlabel('Time--->')
plt.ylabel('Frequency--->')
plt.title('Testing data')
plt.show()

# %%
p1, = plt.plot(df['Dates'],df['driving'],label='driving')
p2, = plt.plot(df['Dates'],df['walking'],label = 'walking')
p3, = plt.plot(df['Dates'],df['transit'],label = 'transit')
p4, = plt.plot(df['Dates'],[100 for i in range(len(df))], label = 'baseline')
plt.legend(handles=[p1, p2, p3,p4], title='Legend', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation='vertical')
plt.xlabel('Time--->')
plt.ylabel('Value--->')
plt.title('Apple Mobility data')
plt.show()

# %%
p1, = plt.plot(df['Dates'],[i+100 for i in df['retail_and_recreation_percent_change_from_baseline'].to_list()],label='retail and recreation')
p2, = plt.plot(df['Dates'],[i+100 for i in df['grocery_and_pharmacy_percent_change_from_baseline'].to_list()],label = 'grocery and pharmacy')
p3, = plt.plot(df['Dates'],[i+100 for i in df['parks_percent_change_from_baseline'].to_list()],label = 'parks')
p4, = plt.plot(df['Dates'],[i+100 for i in df['transit_stations_percent_change_from_baseline'].to_list()], label = 'transit')
p5, = plt.plot(df['Dates'],[i+100 for i in df['workplaces_percent_change_from_baseline'].to_list()], label = 'workplace')
p6, = plt.plot(df['Dates'],[i+100 for i in df['residential_percent_change_from_baseline'].to_list()], label = 'residential')
p7, = plt.plot(df['Dates'],[100 for i in range(len(df))], label = 'baseline')
plt.legend(handles=[p1, p2, p3, p4, p5, p6, p7], title='Legend', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation='vertical')
plt.xlabel('Time--->')
plt.ylabel('Value--->')
plt.title('Google mobility Data')
plt.show()

# %%
plt.plot(df['Dates'],df['stringency_index'])
plt.xticks(rotation='vertical')
plt.xlabel('Time--->')
plt.ylabel('Index--->')
plt.title('Stringecy Index in USA')
plt.show()

# %%
p1, = plt.plot(df['Dates'],df['people_vaccinated'],label='people vaccinated')
p2, = plt.plot(df['Dates'],df['people_fully_vaccinated'],label = 'people fully vaccinated')
# p3, = plt.plot(df['Dates'],df['transit'],label = 'transit')
# p4, = plt.plot(df['Dates'],[100 for i in range(len(df))], label = 'baseline')
plt.legend(handles=[p1, p2], title='Legend', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation='vertical')
plt.xlabel('Time--->')
plt.ylabel('Value--->')
plt.title('Vaccination data')
plt.show()
